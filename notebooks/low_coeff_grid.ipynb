# %%
import pandas as pd
import json
original_path = "/work/pi_jensen_umass_edu/abhishekmish_umass_edu/plan_trace/data/external/all_examples_og_prompt_with_position_info_and_success_V2.json"
scale_folder = "/work/pi_jensen_umass_edu/abhishekmish_umass_edu/plan_trace/outputs/all_scale"

from collections import Counter
import ast

def any_repeated_substring(s, min_repeats=5, max_sub_len=10):
    n = len(s)
    L = max_sub_len
    counts = Counter(s[i:i+L] for i in range(n - L + 1))
    if any(v >= min_repeats for v in counts.values()):
        # print("The max repeating subsequence is - ",counts.most_common(1)[0][0])
        return True
    return False

class Normalizer(ast.NodeTransformer):
    def __init__(self):
        self.var_map = {}
        self.func_map = {}
        self.class_map = {}
        self.counter = 0

    def _rename(self, name, mapping):
        if name not in mapping:
            mapping[name] = f"id_{len(mapping)}"
        return mapping[name]

    def visit_Name(self, node):
        node.id = self._rename(node.id, self.var_map)
        return node

    def visit_arg(self, node):
        node.arg = self._rename(node.arg, self.var_map)
        return node

    def visit_FunctionDef(self, node):
        node.name = self._rename(node.name, self.func_map)
        self.generic_visit(node)
        return node

    def visit_ClassDef(self, node):
        node.name = self._rename(node.name, self.class_map)
        self.generic_visit(node)
        return node


def normalize_ast(code):
    try:
        tree = ast.parse(code)
        norm = Normalizer().visit(tree)
        ast.fix_missing_locations(norm)
        return norm
    except Exception as e:
        # print("problem 1")
        return None

def _is_ast_possible(code):
    try:
        extract = "def" + code.split("```python\n")[-1].split("def")[1]
        ast_tree = normalize_ast(extract)
        return ast_tree != None
    except:
        # print("problem 2", code)
        return False


def _downgrade_plan_to_degenerate(steered_text, baseline_text, original_ym = None):
    """
        - empty string, single character, single string, then classify sa degen.
        - multiple number of 'import' statements in the output without any return statement at the end.
    """
    ## if original_ym is part of the steered text, it's marked as degenerate to prevent a False Positive.
    if original_ym != None and original_ym in steered_text:
        return True
    
    stripped_text = steered_text.strip()
    if stripped_text == "":
        return False #True
    full_code = baseline_text + steered_text
    if not _is_ast_possible(full_code):
        return True
    else: 
        return False
    if (" " not in stripped_text and len(stripped_text) >= 10):
        return True
    if any_repeated_substring(steered_text) and (original_ym == "return" or (original_ym != "return" and "return" not in steered_text)):
        return True
    if original_ym == "return": ## added condition, don't consider planning at 'return' as actual planning evidence of anything actually code related.
        return True
    
    return False

def _classify_as_planning_vs_not_planning(steering_results, planning_analysis, metadata):
    """
        Logic:
            - if already marked as 'Not planning', we keep as-is.
            - if marked as planning, we check for non-degeneracy.
            - if marked as can't say, we check for non-degenaracy and whether the original and new normalized sequences differ by much.
        
        Returns, new planning analysis, with 
        {
            "y_m": {
                "original_verdict": 
                "new_verdict":
             }
            ....
        }
    """
    ym_keys = list(planning_analysis.keys())
    baseline_text = metadata["input_prefix_text"]
    new_planning_analysis = {}
    for y_m in ym_keys:
        new_verdict = planning_analysis[y_m]
        base_suffix = steering_results[y_m]["base_text"]
         
        # if y_m == "return":
        #     new_verdict = "Not planning"
        if planning_analysis[y_m] == "Plan":  
            if not base_suffix.startswith(y_m) and not all([_downgrade_plan_to_degenerate(e.get("decoded_text", ""), baseline_text, y_m) for e in steering_results[y_m]["steered"]]):
                new_verdict = "Plan"
            else:
                # new_verdict = "Not planning"
                new_verdict = "Can't say"

        # elif planning_analysis[y_m] == "Can't say":
        #     new_verdict = "Not planning"                
        
        new_planning_analysis[y_m] = {
            "original_verdict": planning_analysis[y_m],
            "new_verdict": new_verdict
        }
    
    return new_planning_analysis

# %%
import glob
all_tokens = [*glob.glob(scale_folder + "/base/*/*"), *glob.glob(scale_folder + "/instruct/*/*")]
def dump_json(filename, my_dict):
    with open(filename, "w") as f:
        json.dump(my_dict, f, indent=4)  # indent=4 makes it pretty-printed

def load_json(file):
    try:
        with open(file, "r") as f:
            return json.load(f)
    except Exception as e:
        print(f"Exception when loading file {file}")
        raise e

# %%
for token_planning_folder in all_tokens:
    print("/".join(token_planning_folder.split("/")[-3:]))
# Out:
# base/prompt_0/token_188
# base/prompt_0/token_189
# base/prompt_0/token_190
# base/prompt_1/token_115
# base/prompt_1/token_116
# base/prompt_1/token_117
# base/prompt_10/token_94
# base/prompt_10/token_95
# base/prompt_10/token_96
# base/prompt_100/token_164
# base/prompt_100/token_165
# base/prompt_100/token_166
# base/prompt_101/token_292
# base/prompt_101/token_293
# base/prompt_102/token_132
# base/prompt_102/token_133
# base/prompt_102/token_134
# base/prompt_103/token_285
# base/prompt_103/token_286
# base/prompt_103/token_287
# base/prompt_104/token_201
# base/prompt_104/token_202
# base/prompt_105/token_100
# base/prompt_105/token_101
# base/prompt_105/token_99
# base/prompt_107/token_310
# base/prompt_107/token_312
# base/prompt_108/token_207
# base/prompt_108/token_208
# base/prompt_109/token_88
# base/prompt_109/token_89
# base/prompt_11/token_133
# base/prompt_11/token_134
# base/prompt_110/token_111
# base/prompt_110/token_112
# base/prompt_110/token_113
# base/prompt_111/token_211
# base/prompt_111/token_212
# base/prompt_111/token_213
# base/prompt_112/token_117
# base/prompt_112/token_118
# base/prompt_112/token_119
# base/prompt_113/token_197
# base/prompt_113/token_198
# base/prompt_113/token_199
# base/prompt_114/token_238
# base/prompt_114/token_239
# base/prompt_114/token_240
# base/prompt_118/token_275
# base/prompt_118/token_276
# base/prompt_118/token_277
# base/prompt_119/token_139
# base/prompt_119/token_140
# base/prompt_119/token_141
# base/prompt_12/token_129
# base/prompt_12/token_130
# base/prompt_12/token_131
# base/prompt_121/token_205
# base/prompt_121/token_206
# base/prompt_121/token_207
# base/prompt_122/token_226
# base/prompt_122/token_228
# base/prompt_123/token_101
# base/prompt_123/token_102
# base/prompt_123/token_103
# base/prompt_124/token_291
# base/prompt_124/token_293
# base/prompt_125/token_110
# base/prompt_125/token_111
# base/prompt_126/token_125
# base/prompt_126/token_126
# base/prompt_126/token_127
# base/prompt_127/token_97
# base/prompt_127/token_98
# base/prompt_128/token_88
# base/prompt_129/token_219
# base/prompt_129/token_220
# base/prompt_13/token_107
# base/prompt_13/token_108
# base/prompt_13/token_109
# base/prompt_130/token_138
# base/prompt_130/token_139
# base/prompt_130/token_140
# base/prompt_131/token_224
# base/prompt_131/token_225
# base/prompt_131/token_226
# base/prompt_132/token_199
# base/prompt_132/token_200
# base/prompt_133/token_136
# base/prompt_133/token_137
# base/prompt_133/token_138
# base/prompt_134/token_214
# base/prompt_134/token_215
# base/prompt_134/token_216
# base/prompt_135/token_292
# base/prompt_135/token_293
# base/prompt_135/token_294
# base/prompt_136/token_177
# base/prompt_136/token_178
# base/prompt_136/token_179
# base/prompt_137/token_118
# base/prompt_137/token_119
# base/prompt_137/token_120
# base/prompt_138/token_123
# base/prompt_138/token_124
# base/prompt_138/token_125
# base/prompt_139/token_140
# base/prompt_139/token_141
# base/prompt_139/token_142
# base/prompt_14/token_93
# base/prompt_14/token_94
# base/prompt_14/token_95
# base/prompt_140/token_141
# base/prompt_140/token_142
# base/prompt_140/token_143
# base/prompt_141/token_126
# base/prompt_141/token_127
# base/prompt_141/token_128
# base/prompt_142/token_191
# base/prompt_142/token_192
# base/prompt_142/token_193
# base/prompt_143/token_105
# base/prompt_143/token_106
# base/prompt_143/token_107
# base/prompt_144/token_204
# base/prompt_144/token_205
# base/prompt_144/token_206
# base/prompt_145/token_157
# base/prompt_145/token_158
# base/prompt_145/token_159
# base/prompt_146/token_104
# base/prompt_146/token_105
# base/prompt_146/token_106
# base/prompt_147/token_148
# base/prompt_147/token_149
# base/prompt_147/token_150
# base/prompt_149/token_94
# base/prompt_149/token_95
# base/prompt_149/token_96
# base/prompt_15/token_135
# base/prompt_15/token_136
# base/prompt_15/token_137
# base/prompt_150/token_124
# base/prompt_150/token_125
# base/prompt_150/token_126
# base/prompt_151/token_341
# base/prompt_151/token_342
# base/prompt_151/token_343
# base/prompt_152/token_45
# base/prompt_153/token_175
# base/prompt_153/token_176
# base/prompt_153/token_177
# base/prompt_154/token_132
# base/prompt_154/token_133
# base/prompt_154/token_134
# base/prompt_155/token_175
# base/prompt_155/token_176
# base/prompt_156/token_137
# base/prompt_156/token_138
# base/prompt_156/token_139
# base/prompt_157/token_260
# base/prompt_157/token_262
# base/prompt_158/token_170
# base/prompt_158/token_171
# base/prompt_159/token_103
# base/prompt_159/token_104
# base/prompt_159/token_105
# base/prompt_16/token_119
# base/prompt_16/token_120
# base/prompt_16/token_121
# base/prompt_160/token_149
# base/prompt_161/token_125
# base/prompt_161/token_126
# base/prompt_161/token_127
# base/prompt_162/token_214
# base/prompt_162/token_215
# base/prompt_162/token_216
# base/prompt_163/token_125
# base/prompt_163/token_126
# base/prompt_163/token_127
# base/prompt_164/token_103
# base/prompt_164/token_104
# base/prompt_164/token_105
# base/prompt_165/token_181
# base/prompt_165/token_182
# base/prompt_165/token_183
# base/prompt_166/token_24
# base/prompt_167/token_160
# base/prompt_167/token_161
# base/prompt_167/token_162
# base/prompt_168/token_221
# base/prompt_168/token_222
# base/prompt_168/token_223
# base/prompt_169/token_128
# base/prompt_169/token_129
# base/prompt_169/token_130
# base/prompt_17/token_110
# base/prompt_17/token_111
# base/prompt_17/token_112
# base/prompt_170/token_116
# base/prompt_170/token_117
# base/prompt_170/token_118
# base/prompt_171/token_123
# base/prompt_171/token_124
# base/prompt_171/token_125
# base/prompt_172/token_141
# base/prompt_172/token_142
# base/prompt_172/token_143
# base/prompt_173/token_210
# base/prompt_173/token_211
# base/prompt_173/token_212
# base/prompt_174/token_166
# base/prompt_174/token_167
# base/prompt_174/token_168
# base/prompt_175/token_341
# base/prompt_175/token_342
# base/prompt_175/token_343
# base/prompt_176/token_97
# base/prompt_176/token_98
# base/prompt_176/token_99
# base/prompt_177/token_187
# base/prompt_177/token_189
# base/prompt_178/token_100
# base/prompt_178/token_101
# base/prompt_178/token_102
# base/prompt_179/token_218
# base/prompt_179/token_219
# base/prompt_179/token_220
# base/prompt_18/token_122
# base/prompt_18/token_123
# base/prompt_18/token_124
# base/prompt_181/token_146
# base/prompt_181/token_147
# base/prompt_181/token_148
# base/prompt_182/token_122
# base/prompt_182/token_123
# base/prompt_182/token_124
# base/prompt_183/token_123
# base/prompt_183/token_124
# base/prompt_183/token_125
# base/prompt_184/token_301
# base/prompt_184/token_302
# base/prompt_185/token_132
# base/prompt_185/token_133
# base/prompt_185/token_134
# base/prompt_186/token_140
# base/prompt_186/token_141
# base/prompt_186/token_142
# base/prompt_187/token_190
# base/prompt_187/token_191
# base/prompt_187/token_192
# base/prompt_188/token_163
# base/prompt_188/token_164
# base/prompt_188/token_165
# base/prompt_189/token_200
# base/prompt_189/token_201
# base/prompt_19/token_131
# base/prompt_19/token_132
# base/prompt_19/token_133
# base/prompt_190/token_115
# base/prompt_190/token_116
# base/prompt_190/token_117
# base/prompt_191/token_152
# base/prompt_191/token_153
# base/prompt_191/token_154
# base/prompt_192/token_118
# base/prompt_192/token_119
# base/prompt_192/token_120
# base/prompt_193/token_151
# base/prompt_193/token_152
# base/prompt_194/token_209
# base/prompt_194/token_210
# base/prompt_194/token_211
# base/prompt_195/token_180
# base/prompt_195/token_181
# base/prompt_195/token_182
# base/prompt_196/token_170
# base/prompt_196/token_171
# base/prompt_196/token_172
# base/prompt_197/token_265
# base/prompt_197/token_266
# base/prompt_197/token_267
# base/prompt_198/token_202
# base/prompt_198/token_203
# base/prompt_198/token_204
# base/prompt_199/token_121
# base/prompt_199/token_122
# base/prompt_199/token_123
# base/prompt_2/token_190
# base/prompt_2/token_191
# base/prompt_2/token_192
# base/prompt_20/token_193
# base/prompt_20/token_194
# base/prompt_20/token_195
# base/prompt_200/token_151
# base/prompt_200/token_152
# base/prompt_200/token_153
# base/prompt_201/token_128
# base/prompt_201/token_129
# base/prompt_201/token_130
# base/prompt_202/token_140
# base/prompt_202/token_141
# base/prompt_203/token_108
# base/prompt_203/token_109
# base/prompt_203/token_110
# base/prompt_204/token_103
# base/prompt_204/token_104
# base/prompt_204/token_105
# base/prompt_205/token_125
# base/prompt_205/token_126
# base/prompt_205/token_127
# base/prompt_206/token_97
# base/prompt_206/token_98
# base/prompt_206/token_99
# base/prompt_207/token_154
# base/prompt_207/token_155
# base/prompt_207/token_156
# base/prompt_208/token_150
# base/prompt_208/token_151
# base/prompt_208/token_152
# base/prompt_209/token_104
# base/prompt_209/token_105
# base/prompt_209/token_106
# base/prompt_210/token_205
# base/prompt_210/token_206
# base/prompt_210/token_207
# base/prompt_211/token_128
# base/prompt_211/token_129
# base/prompt_211/token_130
# base/prompt_212/token_345
# base/prompt_213/token_340
# base/prompt_214/token_179
# base/prompt_214/token_180
# base/prompt_214/token_181
# base/prompt_215/token_198
# base/prompt_216/token_114
# base/prompt_216/token_115
# base/prompt_216/token_116
# base/prompt_217/token_155
# base/prompt_217/token_156
# base/prompt_218/token_113
# base/prompt_218/token_114
# base/prompt_218/token_115
# base/prompt_219/token_128
# base/prompt_219/token_129
# base/prompt_219/token_130
# base/prompt_22/token_158
# base/prompt_22/token_160
# base/prompt_220/token_113
# base/prompt_220/token_114
# base/prompt_220/token_115
# base/prompt_221/token_106
# base/prompt_221/token_107
# base/prompt_222/token_111
# base/prompt_222/token_112
# base/prompt_222/token_113
# base/prompt_223/token_173
# base/prompt_223/token_174
# base/prompt_223/token_175
# base/prompt_224/token_145
# base/prompt_224/token_146
# base/prompt_224/token_147
# base/prompt_225/token_92
# base/prompt_225/token_93
# base/prompt_226/token_147
# base/prompt_226/token_148
# base/prompt_226/token_149
# base/prompt_227/token_145
# base/prompt_227/token_147
# base/prompt_228/token_100
# base/prompt_228/token_101
# base/prompt_228/token_102
# base/prompt_23/token_123
# base/prompt_23/token_124
# base/prompt_23/token_125
# base/prompt_230/token_159
# base/prompt_230/token_160
# base/prompt_230/token_161
# base/prompt_231/token_200
# base/prompt_231/token_201
# base/prompt_231/token_202
# base/prompt_232/token_167
# base/prompt_232/token_168
# base/prompt_232/token_169
# base/prompt_234/token_184
# base/prompt_234/token_185
# base/prompt_234/token_186
# base/prompt_235/token_136
# base/prompt_235/token_137
# base/prompt_235/token_138
# base/prompt_236/token_123
# base/prompt_236/token_124
# base/prompt_236/token_125
# base/prompt_237/token_119
# base/prompt_237/token_120
# base/prompt_237/token_121
# base/prompt_238/token_224
# base/prompt_238/token_225
# base/prompt_238/token_226
# base/prompt_239/token_116
# base/prompt_239/token_117
# base/prompt_239/token_118
# base/prompt_240/token_104
# base/prompt_240/token_105
# base/prompt_240/token_106
# base/prompt_241/token_105
# base/prompt_241/token_106
# base/prompt_241/token_107
# base/prompt_242/token_103
# base/prompt_242/token_104
# base/prompt_242/token_105
# base/prompt_243/token_135
# base/prompt_243/token_136
# base/prompt_243/token_137
# base/prompt_245/token_141
# base/prompt_245/token_142
# base/prompt_245/token_143
# base/prompt_246/token_107
# base/prompt_246/token_108
# base/prompt_246/token_109
# base/prompt_247/token_201
# base/prompt_247/token_202
# base/prompt_247/token_203
# base/prompt_248/token_242
# base/prompt_248/token_243
# base/prompt_248/token_244
# base/prompt_249/token_169
# base/prompt_249/token_170
# base/prompt_249/token_171
# base/prompt_250/token_136
# base/prompt_250/token_137
# base/prompt_250/token_138
# base/prompt_251/token_146
# base/prompt_251/token_147
# base/prompt_251/token_148
# base/prompt_252/token_111
# base/prompt_252/token_112
# base/prompt_253/token_100
# base/prompt_253/token_101
# base/prompt_253/token_102
# base/prompt_254/token_185
# base/prompt_254/token_186
# base/prompt_254/token_187
# base/prompt_255/token_114
# base/prompt_255/token_115
# base/prompt_255/token_116
# base/prompt_256/token_210
# base/prompt_257/token_173
# base/prompt_257/token_174
# base/prompt_257/token_175
# base/prompt_258/token_162
# base/prompt_258/token_163
# base/prompt_258/token_164
# base/prompt_259/token_134
# base/prompt_259/token_135
# base/prompt_259/token_136
# base/prompt_26/token_143
# base/prompt_26/token_144
# base/prompt_26/token_145
# base/prompt_260/token_141
# base/prompt_260/token_142
# base/prompt_260/token_143
# base/prompt_261/token_113
# base/prompt_261/token_114
# base/prompt_261/token_115
# base/prompt_262/token_318
# base/prompt_262/token_319
# base/prompt_263/token_199
# base/prompt_263/token_200
# base/prompt_264/token_117
# base/prompt_264/token_118
# base/prompt_264/token_119
# base/prompt_265/token_95
# base/prompt_265/token_96
# base/prompt_265/token_97
# base/prompt_266/token_103
# base/prompt_266/token_104
# base/prompt_266/token_105
# base/prompt_267/token_142
# base/prompt_267/token_143
# base/prompt_267/token_144
# base/prompt_268/token_337
# base/prompt_269/token_185
# base/prompt_269/token_186
# base/prompt_27/token_144
# base/prompt_27/token_145
# base/prompt_27/token_146
# base/prompt_270/token_186
# base/prompt_270/token_187
# base/prompt_270/token_188
# base/prompt_271/token_116
# base/prompt_271/token_117
# base/prompt_271/token_118
# base/prompt_272/token_159
# base/prompt_272/token_160
# base/prompt_272/token_161
# base/prompt_273/token_278
# base/prompt_273/token_279
# base/prompt_273/token_280
# base/prompt_274/token_158
# base/prompt_274/token_159
# base/prompt_274/token_160
# base/prompt_275/token_112
# base/prompt_275/token_113
# base/prompt_275/token_114
# base/prompt_276/token_162
# base/prompt_276/token_163
# base/prompt_276/token_164
# base/prompt_277/token_150
# base/prompt_277/token_152
# base/prompt_278/token_136
# base/prompt_278/token_137
# base/prompt_278/token_138
# base/prompt_28/token_188
# base/prompt_28/token_189
# base/prompt_28/token_190
# base/prompt_280/token_103
# base/prompt_280/token_104
# base/prompt_280/token_105
# base/prompt_281/token_127
# base/prompt_281/token_129
# base/prompt_282/token_105
# base/prompt_282/token_106
# base/prompt_282/token_107
# base/prompt_283/token_114
# base/prompt_283/token_115
# base/prompt_283/token_116
# base/prompt_284/token_202
# base/prompt_284/token_203
# base/prompt_285/token_104
# base/prompt_285/token_105
# base/prompt_285/token_106
# base/prompt_286/token_96
# base/prompt_286/token_97
# base/prompt_286/token_98
# base/prompt_287/token_149
# base/prompt_287/token_150
# base/prompt_287/token_151
# base/prompt_288/token_100
# base/prompt_288/token_98
# base/prompt_288/token_99
# base/prompt_289/token_334
# base/prompt_289/token_335
# base/prompt_289/token_336
# base/prompt_29/token_104
# base/prompt_29/token_105
# base/prompt_29/token_106
# base/prompt_290/token_212
# base/prompt_290/token_213
# base/prompt_290/token_214
# base/prompt_291/token_247
# base/prompt_291/token_249
# base/prompt_292/token_171
# base/prompt_292/token_172
# base/prompt_292/token_173
# base/prompt_293/token_349
# base/prompt_293/token_350
# base/prompt_293/token_351
# base/prompt_294/token_202
# base/prompt_294/token_203
# base/prompt_294/token_204
# base/prompt_295/token_136
# base/prompt_295/token_137
# base/prompt_295/token_138
# base/prompt_296/token_171
# base/prompt_296/token_173
# base/prompt_297/token_186
# base/prompt_297/token_187
# base/prompt_297/token_188
# base/prompt_298/token_165
# base/prompt_298/token_166
# base/prompt_298/token_167
# base/prompt_299/token_229
# base/prompt_299/token_230
# base/prompt_3/token_161
# base/prompt_3/token_162
# base/prompt_30/token_143
# base/prompt_30/token_144
# base/prompt_30/token_145
# base/prompt_300/token_201
# base/prompt_300/token_202
# base/prompt_301/token_100
# base/prompt_301/token_98
# base/prompt_301/token_99
# base/prompt_302/token_135
# base/prompt_302/token_136
# base/prompt_302/token_137
# base/prompt_303/token_110
# base/prompt_303/token_111
# base/prompt_303/token_112
# base/prompt_304/token_145
# base/prompt_304/token_146
# base/prompt_304/token_147
# base/prompt_305/token_134
# base/prompt_305/token_135
# base/prompt_306/token_263
# base/prompt_306/token_264
# base/prompt_307/token_125
# base/prompt_307/token_126
# base/prompt_307/token_127
# base/prompt_308/token_140
# base/prompt_308/token_141
# base/prompt_308/token_142
# base/prompt_309/token_231
# base/prompt_309/token_232
# base/prompt_309/token_233
# base/prompt_31/token_224
# base/prompt_31/token_225
# base/prompt_310/token_128
# base/prompt_310/token_129
# base/prompt_310/token_130
# base/prompt_311/token_123
# base/prompt_311/token_124
# base/prompt_311/token_125
# base/prompt_312/token_150
# base/prompt_312/token_151
# base/prompt_312/token_152
# base/prompt_313/token_116
# base/prompt_313/token_117
# base/prompt_313/token_118
# base/prompt_314/token_109
# base/prompt_314/token_110
# base/prompt_314/token_111
# base/prompt_315/token_207
# base/prompt_315/token_208
# base/prompt_315/token_209
# base/prompt_316/token_284
# base/prompt_316/token_285
# base/prompt_316/token_286
# base/prompt_317/token_300
# base/prompt_317/token_301
# base/prompt_317/token_302
# base/prompt_318/token_412
# base/prompt_318/token_413
# base/prompt_319/token_322
# base/prompt_32/token_109
# base/prompt_32/token_110
# base/prompt_32/token_111
# base/prompt_320/token_146
# base/prompt_320/token_147
# base/prompt_320/token_148
# base/prompt_321/token_187
# base/prompt_321/token_188
# base/prompt_321/token_189
# base/prompt_322/token_230
# base/prompt_322/token_231
# base/prompt_322/token_232
# base/prompt_323/token_197
# base/prompt_323/token_199
# base/prompt_324/token_326
# base/prompt_324/token_327
# base/prompt_325/token_170
# base/prompt_326/token_148
# base/prompt_326/token_149
# base/prompt_326/token_150
# base/prompt_327/token_168
# base/prompt_327/token_169
# base/prompt_327/token_170
# base/prompt_328/token_197
# base/prompt_328/token_198
# base/prompt_328/token_199
# base/prompt_329/token_154
# base/prompt_329/token_155
# base/prompt_329/token_156
# base/prompt_33/token_100
# base/prompt_33/token_98
# base/prompt_33/token_99
# base/prompt_330/token_96
# base/prompt_330/token_97
# base/prompt_330/token_98
# base/prompt_331/token_174
# base/prompt_331/token_175
# base/prompt_331/token_176
# base/prompt_332/token_135
# base/prompt_332/token_136
# base/prompt_332/token_137
# base/prompt_333/token_237
# base/prompt_333/token_238
# base/prompt_333/token_239
# base/prompt_334/token_104
# base/prompt_334/token_105
# base/prompt_334/token_106
# base/prompt_335/token_150
# base/prompt_335/token_151
# base/prompt_335/token_152
# base/prompt_336/token_305
# base/prompt_337/token_135
# base/prompt_337/token_136
# base/prompt_337/token_137
# base/prompt_338/token_239
# base/prompt_338/token_240
# base/prompt_339/token_174
# base/prompt_339/token_175
# base/prompt_339/token_176
# base/prompt_34/token_101
# base/prompt_34/token_102
# base/prompt_34/token_103
# base/prompt_340/token_168
# base/prompt_340/token_169
# base/prompt_341/token_124
# base/prompt_341/token_125
# base/prompt_341/token_126
# base/prompt_342/token_358
# base/prompt_343/token_185
# base/prompt_343/token_186
# base/prompt_343/token_187
# base/prompt_344/token_185
# base/prompt_344/token_186
# base/prompt_344/token_187
# base/prompt_345/token_212
# base/prompt_345/token_213
# base/prompt_345/token_214
# base/prompt_346/token_272
# base/prompt_347/token_153
# base/prompt_347/token_154
# base/prompt_347/token_155
# base/prompt_348/token_188
# base/prompt_348/token_189
# base/prompt_348/token_190
# base/prompt_349/token_201
# base/prompt_349/token_202
# base/prompt_349/token_203
# base/prompt_35/token_202
# base/prompt_35/token_203
# base/prompt_35/token_204
# base/prompt_350/token_367
# base/prompt_350/token_368
# base/prompt_350/token_369
# base/prompt_351/token_146
# base/prompt_351/token_147
# base/prompt_351/token_148
# base/prompt_352/token_122
# base/prompt_352/token_123
# base/prompt_352/token_124
# base/prompt_353/token_125
# base/prompt_353/token_126
# base/prompt_353/token_127
# base/prompt_354/token_168
# base/prompt_354/token_169
# base/prompt_354/token_170
# base/prompt_355/token_121
# base/prompt_355/token_122
# base/prompt_355/token_123
# base/prompt_357/token_302
# base/prompt_357/token_303
# base/prompt_357/token_304
# base/prompt_358/token_176
# base/prompt_358/token_177
# base/prompt_358/token_178
# base/prompt_359/token_179
# base/prompt_359/token_180
# base/prompt_36/token_114
# base/prompt_36/token_115
# base/prompt_36/token_116
# base/prompt_360/token_129
# base/prompt_360/token_130
# base/prompt_360/token_131
# base/prompt_361/token_133
# base/prompt_361/token_134
# base/prompt_361/token_135
# base/prompt_362/token_144
# base/prompt_362/token_145
# base/prompt_362/token_146
# base/prompt_363/token_125
# base/prompt_363/token_126
# base/prompt_363/token_127
# base/prompt_364/token_116
# base/prompt_364/token_117
# base/prompt_364/token_118
# base/prompt_365/token_168
# base/prompt_365/token_169
# base/prompt_365/token_170
# base/prompt_366/token_330
# base/prompt_366/token_331
# base/prompt_367/token_126
# base/prompt_367/token_127
# base/prompt_367/token_128
# base/prompt_368/token_144
# base/prompt_368/token_145
# base/prompt_368/token_146
# base/prompt_369/token_249
# base/prompt_37/token_206
# base/prompt_37/token_207
# base/prompt_37/token_208
# base/prompt_370/token_166
# base/prompt_370/token_167
# base/prompt_370/token_168
# base/prompt_371/token_161
# base/prompt_372/token_119
# base/prompt_372/token_120
# base/prompt_372/token_121
# base/prompt_374/token_115
# base/prompt_374/token_117
# base/prompt_375/token_219
# base/prompt_375/token_220
# base/prompt_376/token_140
# base/prompt_376/token_141
# base/prompt_376/token_142
# base/prompt_377/token_121
# base/prompt_377/token_122
# base/prompt_378/token_153
# base/prompt_378/token_154
# base/prompt_378/token_155
# base/prompt_379/token_136
# base/prompt_379/token_137
# base/prompt_379/token_138
# base/prompt_38/token_110
# base/prompt_38/token_111
# base/prompt_38/token_112
# base/prompt_380/token_117
# base/prompt_380/token_118
# base/prompt_380/token_119
# base/prompt_381/token_217
# base/prompt_381/token_218
# base/prompt_381/token_219
# base/prompt_382/token_136
# base/prompt_382/token_137
# base/prompt_382/token_138
# base/prompt_383/token_127
# base/prompt_383/token_128
# base/prompt_383/token_129
# base/prompt_384/token_189
# base/prompt_384/token_190
# base/prompt_384/token_191
# base/prompt_389/token_115
# base/prompt_389/token_116
# base/prompt_389/token_117
# base/prompt_39/token_347
# base/prompt_391/token_162
# base/prompt_391/token_163
# base/prompt_391/token_164
# base/prompt_4/token_181
# base/prompt_4/token_182
# base/prompt_40/token_256
# base/prompt_40/token_257
# base/prompt_40/token_258
# base/prompt_41/token_91
# base/prompt_41/token_92
# base/prompt_42/token_109
# base/prompt_42/token_110
# base/prompt_42/token_111
# base/prompt_43/token_139
# base/prompt_43/token_140
# base/prompt_43/token_141
# base/prompt_44/token_111
# base/prompt_44/token_112
# base/prompt_44/token_113
# base/prompt_45/token_106
# base/prompt_45/token_107
# base/prompt_45/token_108
# base/prompt_46/token_186
# base/prompt_46/token_187
# base/prompt_46/token_188
# base/prompt_47/token_149
# base/prompt_49/token_189
# base/prompt_49/token_190
# base/prompt_5/token_118
# base/prompt_5/token_119
# base/prompt_5/token_120
# base/prompt_50/token_129
# base/prompt_50/token_130
# base/prompt_50/token_131
# base/prompt_51/token_124
# base/prompt_51/token_125
# base/prompt_51/token_126
# base/prompt_52/token_150
# base/prompt_52/token_151
# base/prompt_52/token_152
# base/prompt_53/token_120
# base/prompt_53/token_121
# base/prompt_53/token_122
# base/prompt_55/token_211
# base/prompt_55/token_212
# base/prompt_55/token_213
# base/prompt_56/token_108
# base/prompt_56/token_109
# base/prompt_56/token_110
# base/prompt_57/token_186
# base/prompt_57/token_187
# base/prompt_57/token_188
# base/prompt_58/token_141
# base/prompt_58/token_143
# base/prompt_59/token_288
# base/prompt_59/token_289
# base/prompt_59/token_290
# base/prompt_6/token_114
# base/prompt_6/token_115
# base/prompt_6/token_116
# base/prompt_60/token_100
# base/prompt_60/token_98
# base/prompt_60/token_99
# base/prompt_61/token_104
# base/prompt_61/token_105
# base/prompt_61/token_106
# base/prompt_62/token_122
# base/prompt_62/token_123
# base/prompt_62/token_124
# base/prompt_63/token_332
# base/prompt_63/token_333
# base/prompt_63/token_334
# base/prompt_64/token_115
# base/prompt_65/token_142
# base/prompt_65/token_143
# base/prompt_65/token_144
# base/prompt_67/token_208
# base/prompt_67/token_209
# base/prompt_67/token_210
# base/prompt_68/token_102
# base/prompt_68/token_103
# base/prompt_68/token_104
# base/prompt_69/token_113
# base/prompt_69/token_114
# base/prompt_7/token_265
# base/prompt_7/token_266
# base/prompt_7/token_267
# base/prompt_70/token_206
# base/prompt_70/token_207
# base/prompt_71/token_211
# base/prompt_71/token_212
# base/prompt_71/token_213
# base/prompt_72/token_114
# base/prompt_72/token_115
# base/prompt_72/token_116
# base/prompt_73/token_146
# base/prompt_74/token_197
# base/prompt_74/token_198
# base/prompt_74/token_199
# base/prompt_75/token_100
# base/prompt_75/token_98
# base/prompt_75/token_99
# base/prompt_76/token_261
# base/prompt_76/token_262
# base/prompt_76/token_263
# base/prompt_77/token_146
# base/prompt_77/token_147
# base/prompt_77/token_148
# base/prompt_78/token_175
# base/prompt_79/token_231
# base/prompt_79/token_232
# base/prompt_79/token_233
# base/prompt_8/token_103
# base/prompt_8/token_104
# base/prompt_80/token_205
# base/prompt_80/token_206
# base/prompt_80/token_207
# base/prompt_81/token_278
# base/prompt_82/token_158
# base/prompt_82/token_159
# base/prompt_82/token_160
# base/prompt_83/token_127
# base/prompt_83/token_128
# base/prompt_83/token_129
# base/prompt_85/token_274
# base/prompt_85/token_275
# base/prompt_85/token_276
# base/prompt_86/token_137
# base/prompt_86/token_138
# base/prompt_86/token_139
# base/prompt_87/token_178
# base/prompt_87/token_180
# base/prompt_88/token_113
# base/prompt_88/token_114
# base/prompt_88/token_115
# base/prompt_89/token_149
# base/prompt_89/token_150
# base/prompt_89/token_151
# base/prompt_9/token_125
# base/prompt_9/token_126
# base/prompt_9/token_127
# base/prompt_90/token_120
# base/prompt_90/token_121
# base/prompt_90/token_122
# base/prompt_91/token_136
# base/prompt_91/token_137
# base/prompt_91/token_138
# base/prompt_92/token_213
# base/prompt_92/token_214
# base/prompt_92/token_215
# base/prompt_93/token_112
# base/prompt_93/token_113
# base/prompt_93/token_114
# base/prompt_94/token_153
# base/prompt_94/token_154
# base/prompt_94/token_155
# base/prompt_95/token_135
# base/prompt_95/token_136
# base/prompt_95/token_137
# base/prompt_96/token_237
# base/prompt_96/token_238
# base/prompt_96/token_239
# base/prompt_97/token_115
# base/prompt_97/token_116
# base/prompt_97/token_117
# base/prompt_98/token_127
# base/prompt_98/token_128
# base/prompt_98/token_129
# base/prompt_99/token_124
# base/prompt_99/token_125
# base/prompt_99/token_126
# instruct/prompt_0/token_206
# instruct/prompt_0/token_207
# instruct/prompt_0/token_208
# instruct/prompt_1/token_121
# instruct/prompt_1/token_122
# instruct/prompt_1/token_123
# instruct/prompt_10/token_105
# instruct/prompt_10/token_106
# instruct/prompt_10/token_107
# instruct/prompt_100/token_164
# instruct/prompt_100/token_166
# instruct/prompt_101/token_292
# instruct/prompt_101/token_293
# instruct/prompt_102/token_138
# instruct/prompt_102/token_139
# instruct/prompt_104/token_206
# instruct/prompt_104/token_207
# instruct/prompt_105/token_102
# instruct/prompt_105/token_103
# instruct/prompt_105/token_104
# instruct/prompt_106/token_124
# instruct/prompt_106/token_125
# instruct/prompt_106/token_126
# instruct/prompt_107/token_311
# instruct/prompt_107/token_313
# instruct/prompt_108/token_212
# instruct/prompt_108/token_214
# instruct/prompt_109/token_93
# instruct/prompt_109/token_94
# instruct/prompt_11/token_138
# instruct/prompt_11/token_139
# instruct/prompt_11/token_140
# instruct/prompt_110/token_116
# instruct/prompt_110/token_117
# instruct/prompt_110/token_118
# instruct/prompt_111/token_210
# instruct/prompt_111/token_212
# instruct/prompt_112/token_115
# instruct/prompt_112/token_116
# instruct/prompt_112/token_117
# instruct/prompt_113/token_206
# instruct/prompt_113/token_207
# instruct/prompt_114/token_245
# instruct/prompt_114/token_246
# instruct/prompt_114/token_247
# instruct/prompt_115/token_191
# instruct/prompt_115/token_193
# instruct/prompt_116/token_117
# instruct/prompt_116/token_118
# instruct/prompt_116/token_119
# instruct/prompt_117/token_133
# instruct/prompt_117/token_134
# instruct/prompt_117/token_135
# instruct/prompt_118/token_282
# instruct/prompt_118/token_284
# instruct/prompt_119/token_142
# instruct/prompt_119/token_143
# instruct/prompt_119/token_144
# instruct/prompt_12/token_134
# instruct/prompt_12/token_135
# instruct/prompt_12/token_136
# instruct/prompt_120/token_318
# instruct/prompt_121/token_210
# instruct/prompt_121/token_211
# instruct/prompt_121/token_212
# instruct/prompt_122/token_232
# instruct/prompt_122/token_233
# instruct/prompt_123/token_103
# instruct/prompt_124/token_296
# instruct/prompt_124/token_297
# instruct/prompt_124/token_298
# instruct/prompt_125/token_116
# instruct/prompt_125/token_117
# instruct/prompt_125/token_118
# instruct/prompt_126/token_130
# instruct/prompt_126/token_131
# instruct/prompt_126/token_132
# instruct/prompt_127/token_102
# instruct/prompt_127/token_103
# instruct/prompt_128/token_92
# instruct/prompt_128/token_93
# instruct/prompt_129/token_224
# instruct/prompt_129/token_225
# instruct/prompt_13/token_111
# instruct/prompt_13/token_112
# instruct/prompt_13/token_113
# instruct/prompt_130/token_143
# instruct/prompt_130/token_144
# instruct/prompt_130/token_145
# instruct/prompt_131/token_231
# instruct/prompt_131/token_232
# instruct/prompt_131/token_233
# instruct/prompt_132/token_204
# instruct/prompt_132/token_205
# instruct/prompt_132/token_206
# instruct/prompt_133/token_141
# instruct/prompt_133/token_143
# instruct/prompt_134/token_222
# instruct/prompt_134/token_223
# instruct/prompt_134/token_224
# instruct/prompt_135/token_297
# instruct/prompt_135/token_299
# instruct/prompt_136/token_183
# instruct/prompt_136/token_184
# instruct/prompt_136/token_185
# instruct/prompt_137/token_123
# instruct/prompt_137/token_124
# instruct/prompt_137/token_125
# instruct/prompt_138/token_121
# instruct/prompt_138/token_122
# instruct/prompt_138/token_123
# instruct/prompt_139/token_145
# instruct/prompt_139/token_146
# instruct/prompt_139/token_147
# instruct/prompt_14/token_100
# instruct/prompt_14/token_98
# instruct/prompt_14/token_99
# instruct/prompt_140/token_146
# instruct/prompt_140/token_148
# instruct/prompt_141/token_131
# instruct/prompt_141/token_132
# instruct/prompt_141/token_133
# instruct/prompt_142/token_189
# instruct/prompt_142/token_190
# instruct/prompt_142/token_191
# instruct/prompt_143/token_125
# instruct/prompt_143/token_126
# instruct/prompt_143/token_127
# instruct/prompt_144/token_206
# instruct/prompt_144/token_207
# instruct/prompt_144/token_208
# instruct/prompt_145/token_155
# instruct/prompt_145/token_157
# instruct/prompt_146/token_109
# instruct/prompt_146/token_110
# instruct/prompt_146/token_111
# instruct/prompt_147/token_156
# instruct/prompt_147/token_157
# instruct/prompt_148/token_151
# instruct/prompt_148/token_152
# instruct/prompt_148/token_153
# instruct/prompt_149/token_100
# instruct/prompt_149/token_101
# instruct/prompt_149/token_99
# instruct/prompt_15/token_140
# instruct/prompt_15/token_142
# instruct/prompt_150/token_129
# instruct/prompt_150/token_130
# instruct/prompt_150/token_131
# instruct/prompt_151/token_345
# instruct/prompt_151/token_346
# instruct/prompt_152/token_231
# instruct/prompt_152/token_232
# instruct/prompt_153/token_180
# instruct/prompt_153/token_181
# instruct/prompt_153/token_182
# instruct/prompt_154/token_137
# instruct/prompt_154/token_138
# instruct/prompt_154/token_139
# instruct/prompt_155/token_173
# instruct/prompt_155/token_174
# instruct/prompt_155/token_175
# instruct/prompt_156/token_142
# instruct/prompt_156/token_144
# instruct/prompt_157/token_266
# instruct/prompt_157/token_267
# instruct/prompt_158/token_179
# instruct/prompt_158/token_180
# instruct/prompt_159/token_109
# instruct/prompt_159/token_110
# instruct/prompt_159/token_111
# instruct/prompt_16/token_124
# instruct/prompt_16/token_125
# instruct/prompt_16/token_126
# instruct/prompt_160/token_153
# instruct/prompt_160/token_154
# instruct/prompt_161/token_130
# instruct/prompt_161/token_131
# instruct/prompt_161/token_132
# instruct/prompt_162/token_222
# instruct/prompt_162/token_223
# instruct/prompt_162/token_224
# instruct/prompt_163/token_130
# instruct/prompt_163/token_131
# instruct/prompt_163/token_132
# instruct/prompt_164/token_109
# instruct/prompt_164/token_110
# instruct/prompt_164/token_111
# instruct/prompt_165/token_186
# instruct/prompt_165/token_188
# instruct/prompt_166/token_367
# instruct/prompt_166/token_369
# instruct/prompt_167/token_165
# instruct/prompt_167/token_166
# instruct/prompt_167/token_167
# instruct/prompt_168/token_226
# instruct/prompt_168/token_227
# instruct/prompt_169/token_134
# instruct/prompt_169/token_135
# instruct/prompt_169/token_136
# instruct/prompt_17/token_115
# instruct/prompt_17/token_116
# instruct/prompt_17/token_117
# instruct/prompt_170/token_122
# instruct/prompt_170/token_123
# instruct/prompt_170/token_124
# instruct/prompt_171/token_128
# instruct/prompt_171/token_129
# instruct/prompt_172/token_146
# instruct/prompt_172/token_148
# instruct/prompt_173/token_213
# instruct/prompt_173/token_214
# instruct/prompt_173/token_215
# instruct/prompt_174/token_173
# instruct/prompt_174/token_175
# instruct/prompt_175/token_344
# instruct/prompt_176/token_102
# instruct/prompt_176/token_103
# instruct/prompt_176/token_104
# instruct/prompt_177/token_193
# instruct/prompt_177/token_195
# instruct/prompt_178/token_104
# instruct/prompt_178/token_105
# instruct/prompt_178/token_106
# instruct/prompt_179/token_216
# instruct/prompt_179/token_217
# instruct/prompt_179/token_218
# instruct/prompt_18/token_127
# instruct/prompt_18/token_128
# instruct/prompt_18/token_129
# instruct/prompt_180/token_184
# instruct/prompt_180/token_185
# instruct/prompt_180/token_186
# instruct/prompt_181/token_151
# instruct/prompt_181/token_152
# instruct/prompt_181/token_153
# instruct/prompt_182/token_127
# instruct/prompt_182/token_128
# instruct/prompt_182/token_129
# instruct/prompt_183/token_128
# instruct/prompt_183/token_129
# instruct/prompt_183/token_130
# instruct/prompt_184/token_306
# instruct/prompt_184/token_307
# instruct/prompt_184/token_308
# instruct/prompt_185/token_138
# instruct/prompt_185/token_139
# instruct/prompt_186/token_145
# instruct/prompt_186/token_146
# instruct/prompt_186/token_147
# instruct/prompt_187/token_198
# instruct/prompt_187/token_199
# instruct/prompt_188/token_168
# instruct/prompt_188/token_169
# instruct/prompt_188/token_170
# instruct/prompt_189/token_205
# instruct/prompt_189/token_207
# instruct/prompt_19/token_136
# instruct/prompt_19/token_137
# instruct/prompt_19/token_138
# instruct/prompt_190/token_120
# instruct/prompt_190/token_121
# instruct/prompt_190/token_122
# instruct/prompt_191/token_158
# instruct/prompt_191/token_160
# instruct/prompt_192/token_123
# instruct/prompt_192/token_125
# instruct/prompt_193/token_153
# instruct/prompt_193/token_154
# instruct/prompt_193/token_155
# instruct/prompt_194/token_214
# instruct/prompt_194/token_215
# instruct/prompt_194/token_216
# instruct/prompt_195/token_185
# instruct/prompt_195/token_187
# instruct/prompt_196/token_177
# instruct/prompt_196/token_178
# instruct/prompt_196/token_179
# instruct/prompt_197/token_271
# instruct/prompt_197/token_272
# instruct/prompt_198/token_210
# instruct/prompt_198/token_211
# instruct/prompt_199/token_129
# instruct/prompt_199/token_130
# instruct/prompt_2/token_195
# instruct/prompt_2/token_197
# instruct/prompt_20/token_198
# instruct/prompt_20/token_199
# instruct/prompt_20/token_200
# instruct/prompt_200/token_156
# instruct/prompt_200/token_157
# instruct/prompt_200/token_158
# instruct/prompt_201/token_133
# instruct/prompt_201/token_134
# instruct/prompt_201/token_135
# instruct/prompt_202/token_145
# instruct/prompt_202/token_146
# instruct/prompt_203/token_113
# instruct/prompt_203/token_114
# instruct/prompt_203/token_115
# instruct/prompt_204/token_107
# instruct/prompt_204/token_108
# instruct/prompt_204/token_109
# instruct/prompt_205/token_130
# instruct/prompt_205/token_131
# instruct/prompt_206/token_102
# instruct/prompt_206/token_104
# instruct/prompt_207/token_155
# instruct/prompt_207/token_156
# instruct/prompt_207/token_157
# instruct/prompt_208/token_157
# instruct/prompt_208/token_158
# instruct/prompt_208/token_159
# instruct/prompt_209/token_110
# instruct/prompt_209/token_111
# instruct/prompt_21/token_222
# instruct/prompt_21/token_223
# instruct/prompt_210/token_38
# instruct/prompt_211/token_127
# instruct/prompt_211/token_128
# instruct/prompt_211/token_129
# instruct/prompt_212/token_351
# instruct/prompt_212/token_352
# instruct/prompt_213/token_340
# instruct/prompt_213/token_341
# instruct/prompt_214/token_184
# instruct/prompt_214/token_185
# instruct/prompt_214/token_186
# instruct/prompt_215/token_202
# instruct/prompt_215/token_203
# instruct/prompt_216/token_119
# instruct/prompt_216/token_120
# instruct/prompt_216/token_121
# instruct/prompt_217/token_160
# instruct/prompt_217/token_161
# instruct/prompt_217/token_162
# instruct/prompt_218/token_118
# instruct/prompt_218/token_119
# instruct/prompt_218/token_120
# instruct/prompt_219/token_126
# instruct/prompt_219/token_127
# instruct/prompt_22/token_163
# instruct/prompt_22/token_164
# instruct/prompt_22/token_165
# instruct/prompt_220/token_118
# instruct/prompt_220/token_119
# instruct/prompt_220/token_120
# instruct/prompt_221/token_111
# instruct/prompt_221/token_112
# instruct/prompt_221/token_113
# instruct/prompt_222/token_114
# instruct/prompt_222/token_115
# instruct/prompt_222/token_116
# instruct/prompt_223/token_178
# instruct/prompt_223/token_179
# instruct/prompt_223/token_180
# instruct/prompt_224/token_150
# instruct/prompt_224/token_151
# instruct/prompt_224/token_152
# instruct/prompt_225/token_97
# instruct/prompt_225/token_98
# instruct/prompt_226/token_152
# instruct/prompt_226/token_153
# instruct/prompt_226/token_154
# instruct/prompt_227/token_150
# instruct/prompt_227/token_151
# instruct/prompt_227/token_152
# instruct/prompt_228/token_105
# instruct/prompt_228/token_106
# instruct/prompt_228/token_107
# instruct/prompt_23/token_128
# instruct/prompt_23/token_129
# instruct/prompt_23/token_130
# instruct/prompt_230/token_164
# instruct/prompt_230/token_165
# instruct/prompt_230/token_166
# instruct/prompt_231/token_205
# instruct/prompt_231/token_207
# instruct/prompt_232/token_174
# instruct/prompt_233/token_184
# instruct/prompt_233/token_185
# instruct/prompt_233/token_186
# instruct/prompt_234/token_189
# instruct/prompt_234/token_190
# instruct/prompt_234/token_191
# instruct/prompt_235/token_141
# instruct/prompt_235/token_142
# instruct/prompt_235/token_143
# instruct/prompt_236/token_128
# instruct/prompt_236/token_129
# instruct/prompt_236/token_130
# instruct/prompt_237/token_125
# instruct/prompt_237/token_126
# instruct/prompt_238/token_229
# instruct/prompt_238/token_230
# instruct/prompt_238/token_231
# instruct/prompt_239/token_121
# instruct/prompt_239/token_122
# instruct/prompt_239/token_123
# instruct/prompt_24/token_162
# instruct/prompt_24/token_164
# instruct/prompt_240/token_109
# instruct/prompt_240/token_110
# instruct/prompt_240/token_111
# instruct/prompt_241/token_110
# instruct/prompt_241/token_111
# instruct/prompt_241/token_112
# instruct/prompt_242/token_108
# instruct/prompt_242/token_109
# instruct/prompt_242/token_110
# instruct/prompt_243/token_140
# instruct/prompt_243/token_141
# instruct/prompt_243/token_142
# instruct/prompt_244/token_118
# instruct/prompt_244/token_119
# instruct/prompt_244/token_120
# instruct/prompt_245/token_146
# instruct/prompt_245/token_147
# instruct/prompt_245/token_148
# instruct/prompt_246/token_112
# instruct/prompt_246/token_113
# instruct/prompt_246/token_114
# instruct/prompt_247/token_199
# instruct/prompt_247/token_200
# instruct/prompt_247/token_201
# instruct/prompt_248/token_247
# instruct/prompt_248/token_248
# instruct/prompt_248/token_249
# instruct/prompt_249/token_174
# instruct/prompt_249/token_175
# instruct/prompt_249/token_176
# instruct/prompt_25/token_128
# instruct/prompt_25/token_130
# instruct/prompt_250/token_141
# instruct/prompt_250/token_143
# instruct/prompt_251/token_136
# instruct/prompt_251/token_137
# instruct/prompt_251/token_138
# instruct/prompt_252/token_116
# instruct/prompt_252/token_117
# instruct/prompt_253/token_105
# instruct/prompt_253/token_106
# instruct/prompt_253/token_107
# instruct/prompt_254/token_190
# instruct/prompt_254/token_191
# instruct/prompt_254/token_192
# instruct/prompt_255/token_119
# instruct/prompt_255/token_120
# instruct/prompt_255/token_121
# instruct/prompt_256/token_215
# instruct/prompt_257/token_171
# instruct/prompt_257/token_172
# instruct/prompt_257/token_173
# instruct/prompt_258/token_167
# instruct/prompt_258/token_168
# instruct/prompt_258/token_169
# instruct/prompt_259/token_142
# instruct/prompt_259/token_143
# instruct/prompt_259/token_144
# instruct/prompt_26/token_147
# instruct/prompt_26/token_148
# instruct/prompt_26/token_149
# instruct/prompt_260/token_146
# instruct/prompt_260/token_148
# instruct/prompt_261/token_118
# instruct/prompt_261/token_119
# instruct/prompt_261/token_120
# instruct/prompt_262/token_323
# instruct/prompt_262/token_324
# instruct/prompt_262/token_325
# instruct/prompt_263/token_204
# instruct/prompt_263/token_205
# instruct/prompt_264/token_123
# instruct/prompt_264/token_124
# instruct/prompt_264/token_125
# instruct/prompt_265/token_20
# instruct/prompt_265/token_21
# instruct/prompt_265/token_22
# instruct/prompt_266/token_108
# instruct/prompt_266/token_109
# instruct/prompt_266/token_110
# instruct/prompt_267/token_147
# instruct/prompt_267/token_149
# instruct/prompt_268/token_340
# instruct/prompt_268/token_341
# instruct/prompt_268/token_342
# instruct/prompt_269/token_192
# instruct/prompt_27/token_149
# instruct/prompt_27/token_150
# instruct/prompt_27/token_151
# instruct/prompt_270/token_191
# instruct/prompt_270/token_192
# instruct/prompt_270/token_193
# instruct/prompt_271/token_121
# instruct/prompt_271/token_122
# instruct/prompt_271/token_123
# instruct/prompt_272/token_164
# instruct/prompt_272/token_165
# instruct/prompt_272/token_166
# instruct/prompt_273/token_288
# instruct/prompt_274/token_163
# instruct/prompt_274/token_164
# instruct/prompt_274/token_165
# instruct/prompt_275/token_117
# instruct/prompt_275/token_119
# instruct/prompt_276/token_167
# instruct/prompt_276/token_168
# instruct/prompt_276/token_169
# instruct/prompt_277/token_155
# instruct/prompt_277/token_157
# instruct/prompt_278/token_143
# instruct/prompt_278/token_144
# instruct/prompt_278/token_145
# instruct/prompt_279/token_231
# instruct/prompt_279/token_232
# instruct/prompt_279/token_233
# instruct/prompt_28/token_193
# instruct/prompt_28/token_194
# instruct/prompt_28/token_195
# instruct/prompt_280/token_108
# instruct/prompt_280/token_109
# instruct/prompt_280/token_110
# instruct/prompt_281/token_132
# instruct/prompt_281/token_133
# instruct/prompt_281/token_134
# instruct/prompt_282/token_111
# instruct/prompt_282/token_112
# instruct/prompt_282/token_113
# instruct/prompt_283/token_119
# instruct/prompt_283/token_120
# instruct/prompt_283/token_121
# instruct/prompt_284/token_207
# instruct/prompt_284/token_209
# instruct/prompt_285/token_109
# instruct/prompt_285/token_110
# instruct/prompt_285/token_111
# instruct/prompt_286/token_102
# instruct/prompt_286/token_103
# instruct/prompt_286/token_104
# instruct/prompt_287/token_154
# instruct/prompt_287/token_155
# instruct/prompt_287/token_156
# instruct/prompt_288/token_103
# instruct/prompt_288/token_104
# instruct/prompt_288/token_105
# instruct/prompt_289/token_339
# instruct/prompt_289/token_341
# instruct/prompt_29/token_109
# instruct/prompt_29/token_111
# instruct/prompt_290/token_211
# instruct/prompt_290/token_213
# instruct/prompt_291/token_251
# instruct/prompt_291/token_252
# instruct/prompt_291/token_253
# instruct/prompt_292/token_19
# instruct/prompt_292/token_20
# instruct/prompt_292/token_21
# instruct/prompt_293/token_355
# instruct/prompt_294/token_207
# instruct/prompt_294/token_208
# instruct/prompt_294/token_209
# instruct/prompt_295/token_141
# instruct/prompt_295/token_142
# instruct/prompt_295/token_143
# instruct/prompt_296/token_176
# instruct/prompt_296/token_177
# instruct/prompt_296/token_178
# instruct/prompt_297/token_185
# instruct/prompt_297/token_187
# instruct/prompt_298/token_163
# instruct/prompt_298/token_165
# instruct/prompt_299/token_227
# instruct/prompt_299/token_229
# instruct/prompt_3/token_166
# instruct/prompt_3/token_168
# instruct/prompt_30/token_142
# instruct/prompt_30/token_143
# instruct/prompt_30/token_144
# instruct/prompt_300/token_207
# instruct/prompt_301/token_103
# instruct/prompt_301/token_104
# instruct/prompt_301/token_105
# instruct/prompt_302/token_140
# instruct/prompt_302/token_141
# instruct/prompt_302/token_142
# instruct/prompt_303/token_117
# instruct/prompt_303/token_118
# instruct/prompt_303/token_119
# instruct/prompt_304/token_150
# instruct/prompt_304/token_151
# instruct/prompt_304/token_152
# instruct/prompt_305/token_138
# instruct/prompt_305/token_139
# instruct/prompt_305/token_140
# instruct/prompt_306/token_21
# instruct/prompt_306/token_22
# instruct/prompt_306/token_23
# instruct/prompt_307/token_130
# instruct/prompt_307/token_131
# instruct/prompt_307/token_132
# instruct/prompt_308/token_136
# instruct/prompt_308/token_138
# instruct/prompt_309/token_236
# instruct/prompt_309/token_237
# instruct/prompt_309/token_238
# instruct/prompt_31/token_231
# instruct/prompt_31/token_233
# instruct/prompt_310/token_135
# instruct/prompt_311/token_128
# instruct/prompt_311/token_129
# instruct/prompt_311/token_130
# instruct/prompt_312/token_155
# instruct/prompt_312/token_156
# instruct/prompt_312/token_157
# instruct/prompt_313/token_121
# instruct/prompt_313/token_122
# instruct/prompt_313/token_123
# instruct/prompt_314/token_114
# instruct/prompt_314/token_115
# instruct/prompt_314/token_116
# instruct/prompt_315/token_205
# instruct/prompt_315/token_206
# instruct/prompt_315/token_207
# instruct/prompt_316/token_280
# instruct/prompt_317/token_298
# instruct/prompt_317/token_300
# instruct/prompt_318/token_417
# instruct/prompt_318/token_419
# instruct/prompt_319/token_326
# instruct/prompt_319/token_327
# instruct/prompt_32/token_114
# instruct/prompt_32/token_115
# instruct/prompt_32/token_116
# instruct/prompt_320/token_151
# instruct/prompt_320/token_152
# instruct/prompt_320/token_153
# instruct/prompt_321/token_192
# instruct/prompt_321/token_194
# instruct/prompt_322/token_235
# instruct/prompt_322/token_237
# instruct/prompt_323/token_204
# instruct/prompt_323/token_206
# instruct/prompt_324/token_325
# instruct/prompt_324/token_327
# instruct/prompt_325/token_178
# instruct/prompt_325/token_179
# instruct/prompt_326/token_153
# instruct/prompt_326/token_154
# instruct/prompt_326/token_155
# instruct/prompt_327/token_167
# instruct/prompt_327/token_169
# instruct/prompt_328/token_202
# instruct/prompt_328/token_204
# instruct/prompt_329/token_159
# instruct/prompt_329/token_160
# instruct/prompt_329/token_161
# instruct/prompt_33/token_103
# instruct/prompt_33/token_104
# instruct/prompt_33/token_105
# instruct/prompt_330/token_104
# instruct/prompt_330/token_105
# instruct/prompt_330/token_106
# instruct/prompt_331/token_179
# instruct/prompt_331/token_181
# instruct/prompt_332/token_140
# instruct/prompt_332/token_141
# instruct/prompt_332/token_142
# instruct/prompt_333/token_243
# instruct/prompt_333/token_245
# instruct/prompt_334/token_110
# instruct/prompt_334/token_111
# instruct/prompt_335/token_157
# instruct/prompt_335/token_158
# instruct/prompt_335/token_159
# instruct/prompt_336/token_308
# instruct/prompt_337/token_140
# instruct/prompt_337/token_141
# instruct/prompt_337/token_142
# instruct/prompt_338/token_244
# instruct/prompt_338/token_246
# instruct/prompt_339/token_182
# instruct/prompt_339/token_183
# instruct/prompt_339/token_184
# instruct/prompt_34/token_106
# instruct/prompt_34/token_108
# instruct/prompt_340/token_173
# instruct/prompt_341/token_129
# instruct/prompt_341/token_130
# instruct/prompt_341/token_131
# instruct/prompt_342/token_363
# instruct/prompt_343/token_192
# instruct/prompt_343/token_193
# instruct/prompt_343/token_194
# instruct/prompt_344/token_190
# instruct/prompt_344/token_192
# instruct/prompt_345/token_217
# instruct/prompt_345/token_219
# instruct/prompt_346/token_270
# instruct/prompt_346/token_272
# instruct/prompt_347/token_151
# instruct/prompt_347/token_152
# instruct/prompt_347/token_153
# instruct/prompt_348/token_196
# instruct/prompt_348/token_197
# instruct/prompt_348/token_198
# instruct/prompt_349/token_206
# instruct/prompt_349/token_207
# instruct/prompt_349/token_208
# instruct/prompt_35/token_210
# instruct/prompt_35/token_211
# instruct/prompt_35/token_212
# instruct/prompt_350/token_374
# instruct/prompt_351/token_151
# instruct/prompt_351/token_152
# instruct/prompt_351/token_153
# instruct/prompt_352/token_127
# instruct/prompt_352/token_128
# instruct/prompt_352/token_129
# instruct/prompt_353/token_128
# instruct/prompt_353/token_129
# instruct/prompt_353/token_130
# instruct/prompt_354/token_173
# instruct/prompt_354/token_174
# instruct/prompt_354/token_175
# instruct/prompt_355/token_126
# instruct/prompt_355/token_127
# instruct/prompt_355/token_128
# instruct/prompt_356/token_106
# instruct/prompt_356/token_107
# instruct/prompt_357/token_307
# instruct/prompt_357/token_308
# instruct/prompt_357/token_309
# instruct/prompt_358/token_174
# instruct/prompt_358/token_175
# instruct/prompt_358/token_176
# instruct/prompt_359/token_184
# instruct/prompt_359/token_185
# instruct/prompt_36/token_119
# instruct/prompt_36/token_120
# instruct/prompt_36/token_121
# instruct/prompt_360/token_134
# instruct/prompt_360/token_135
# instruct/prompt_360/token_136
# instruct/prompt_361/token_44
# instruct/prompt_361/token_45
# instruct/prompt_361/token_46
# instruct/prompt_362/token_149
# instruct/prompt_362/token_150
# instruct/prompt_362/token_151
# instruct/prompt_363/token_130
# instruct/prompt_363/token_131
# instruct/prompt_363/token_132
# instruct/prompt_364/token_121
# instruct/prompt_364/token_122
# instruct/prompt_364/token_123
# instruct/prompt_365/token_166
# instruct/prompt_365/token_167
# instruct/prompt_365/token_168
# instruct/prompt_366/token_330
# instruct/prompt_366/token_331
# instruct/prompt_367/token_131
# instruct/prompt_367/token_132
# instruct/prompt_367/token_133
# instruct/prompt_368/token_149
# instruct/prompt_368/token_151
# instruct/prompt_369/token_253
# instruct/prompt_369/token_254
# instruct/prompt_37/token_214
# instruct/prompt_37/token_215
# instruct/prompt_37/token_216
# instruct/prompt_370/token_171
# instruct/prompt_370/token_172
# instruct/prompt_370/token_173
# instruct/prompt_371/token_166
# instruct/prompt_372/token_124
# instruct/prompt_372/token_125
# instruct/prompt_372/token_126
# instruct/prompt_373/token_141
# instruct/prompt_373/token_142
# instruct/prompt_373/token_143
# instruct/prompt_374/token_120
# instruct/prompt_374/token_121
# instruct/prompt_374/token_122
# instruct/prompt_375/token_225
# instruct/prompt_375/token_227
# instruct/prompt_376/token_158
# instruct/prompt_376/token_159
# instruct/prompt_376/token_160
# instruct/prompt_377/token_126
# instruct/prompt_377/token_127
# instruct/prompt_377/token_128
# instruct/prompt_378/token_158
# instruct/prompt_378/token_160
# instruct/prompt_379/token_141
# instruct/prompt_379/token_142
# instruct/prompt_379/token_143
# instruct/prompt_38/token_115
# instruct/prompt_38/token_116
# instruct/prompt_38/token_117
# instruct/prompt_380/token_122
# instruct/prompt_380/token_124
# instruct/prompt_381/token_223
# instruct/prompt_382/token_141
# instruct/prompt_382/token_142
# instruct/prompt_382/token_143
# instruct/prompt_383/token_132
# instruct/prompt_383/token_133
# instruct/prompt_383/token_134
# instruct/prompt_384/token_187
# instruct/prompt_384/token_188
# instruct/prompt_384/token_189
# instruct/prompt_385/token_171
# instruct/prompt_386/token_118
# instruct/prompt_386/token_119
# instruct/prompt_386/token_120
# instruct/prompt_387/token_200
# instruct/prompt_387/token_201
# instruct/prompt_387/token_202
# instruct/prompt_388/token_138
# instruct/prompt_388/token_139
# instruct/prompt_388/token_140
# instruct/prompt_389/token_121
# instruct/prompt_389/token_122
# instruct/prompt_39/token_352
# instruct/prompt_39/token_353
# instruct/prompt_39/token_354
# instruct/prompt_390/token_163
# instruct/prompt_390/token_164
# instruct/prompt_390/token_165
# instruct/prompt_391/token_169
# instruct/prompt_4/token_186
# instruct/prompt_4/token_187
# instruct/prompt_40/token_261
# instruct/prompt_40/token_262
# instruct/prompt_40/token_263
# instruct/prompt_41/token_96
# instruct/prompt_41/token_97
# instruct/prompt_42/token_114
# instruct/prompt_42/token_115
# instruct/prompt_42/token_116
# instruct/prompt_43/token_144
# instruct/prompt_43/token_145
# instruct/prompt_43/token_146
# instruct/prompt_44/token_115
# instruct/prompt_44/token_116
# instruct/prompt_44/token_117
# instruct/prompt_45/token_111
# instruct/prompt_45/token_112
# instruct/prompt_45/token_113
# instruct/prompt_46/token_191
# instruct/prompt_46/token_193
# instruct/prompt_47/token_150
# instruct/prompt_47/token_151
# instruct/prompt_47/token_152
# instruct/prompt_48/token_97
# instruct/prompt_48/token_98
# instruct/prompt_48/token_99
# instruct/prompt_49/token_192
# instruct/prompt_49/token_194
# instruct/prompt_5/token_116
# instruct/prompt_5/token_117
# instruct/prompt_5/token_118
# instruct/prompt_50/token_132
# instruct/prompt_50/token_133
# instruct/prompt_50/token_134
# instruct/prompt_51/token_122
# instruct/prompt_51/token_124
# instruct/prompt_52/token_155
# instruct/prompt_52/token_156
# instruct/prompt_53/token_125
# instruct/prompt_53/token_126
# instruct/prompt_53/token_127
# instruct/prompt_54/token_138
# instruct/prompt_54/token_139
# instruct/prompt_54/token_140
# instruct/prompt_55/token_215
# instruct/prompt_55/token_217
# instruct/prompt_56/token_113
# instruct/prompt_56/token_114
# instruct/prompt_56/token_115
# instruct/prompt_57/token_193
# instruct/prompt_58/token_135
# instruct/prompt_58/token_137
# instruct/prompt_59/token_293
# instruct/prompt_59/token_294
# instruct/prompt_59/token_295
# instruct/prompt_6/token_119
# instruct/prompt_6/token_120
# instruct/prompt_6/token_121
# instruct/prompt_60/token_104
# instruct/prompt_60/token_105
# instruct/prompt_60/token_106
# instruct/prompt_61/token_109
# instruct/prompt_61/token_110
# instruct/prompt_61/token_111
# instruct/prompt_62/token_128
# instruct/prompt_62/token_129
# instruct/prompt_62/token_130
# instruct/prompt_63/token_335
# instruct/prompt_64/token_119
# instruct/prompt_64/token_120
# instruct/prompt_65/token_148
# instruct/prompt_65/token_149
# instruct/prompt_65/token_150
# instruct/prompt_66/token_186
# instruct/prompt_66/token_187
# instruct/prompt_66/token_188
# instruct/prompt_67/token_216
# instruct/prompt_67/token_218
# instruct/prompt_68/token_107
# instruct/prompt_68/token_108
# instruct/prompt_68/token_109
# instruct/prompt_69/token_118
# instruct/prompt_69/token_119
# instruct/prompt_7/token_247
# instruct/prompt_7/token_248
# instruct/prompt_7/token_249
# instruct/prompt_70/token_206
# instruct/prompt_70/token_207
# instruct/prompt_70/token_208
# instruct/prompt_71/token_216
# instruct/prompt_71/token_217
# instruct/prompt_71/token_218
# instruct/prompt_72/token_119
# instruct/prompt_72/token_120
# instruct/prompt_72/token_121
# instruct/prompt_73/token_149
# instruct/prompt_73/token_150
# instruct/prompt_73/token_151
# instruct/prompt_74/token_202
# instruct/prompt_74/token_203
# instruct/prompt_74/token_204
# instruct/prompt_75/token_103
# instruct/prompt_75/token_104
# instruct/prompt_75/token_105
# instruct/prompt_76/token_47
# instruct/prompt_76/token_48
# instruct/prompt_76/token_49
# instruct/prompt_77/token_145
# instruct/prompt_77/token_146
# instruct/prompt_78/token_179
# instruct/prompt_78/token_180
# instruct/prompt_79/token_240
# instruct/prompt_8/token_108
# instruct/prompt_8/token_109
# instruct/prompt_80/token_203
# instruct/prompt_80/token_204
# instruct/prompt_80/token_205
# instruct/prompt_81/token_283
# instruct/prompt_81/token_284
# instruct/prompt_82/token_164
# instruct/prompt_82/token_165
# instruct/prompt_82/token_166
# instruct/prompt_83/token_132
# instruct/prompt_83/token_134
# instruct/prompt_84/token_136
# instruct/prompt_85/token_279
# instruct/prompt_85/token_281
# instruct/prompt_86/token_142
# instruct/prompt_86/token_144
# instruct/prompt_87/token_188
# instruct/prompt_87/token_189
# instruct/prompt_87/token_190
# instruct/prompt_88/token_120
# instruct/prompt_88/token_121
# instruct/prompt_88/token_122
# instruct/prompt_89/token_154
# instruct/prompt_89/token_155
# instruct/prompt_89/token_156
# instruct/prompt_9/token_130
# instruct/prompt_9/token_132
# instruct/prompt_90/token_125
# instruct/prompt_90/token_127
# instruct/prompt_91/token_141
# instruct/prompt_91/token_142
# instruct/prompt_91/token_143
# instruct/prompt_92/token_218
# instruct/prompt_92/token_220
# instruct/prompt_93/token_118
# instruct/prompt_93/token_119
# instruct/prompt_93/token_120
# instruct/prompt_94/token_158
# instruct/prompt_94/token_159
# instruct/prompt_94/token_160
# instruct/prompt_95/token_142
# instruct/prompt_95/token_143
# instruct/prompt_96/token_242
# instruct/prompt_96/token_243
# instruct/prompt_96/token_244
# instruct/prompt_97/token_120
# instruct/prompt_97/token_121
# instruct/prompt_97/token_122
# instruct/prompt_98/token_132
# instruct/prompt_98/token_133
# instruct/prompt_98/token_134
# instruct/prompt_99/token_129
# instruct/prompt_99/token_130
# instruct/prompt_99/token_131

# %%
import os
local_path = "/home/jnainani_umass_edu/w/plan_trace/outputs/scale_bvi_v7/"

for token_planning_folder in all_tokens:
    # json_files = glob.glob(f"{token_planning_folder}/*.json")
    # metadata, planning_analysis, steering_results = load_json(json_files[1]), load_json(json_files[2]), load_json(json_files[3])
    planning_analysis = load_json(f"{token_planning_folder}/planning_analysis.json")
    steering_results = load_json(f"{token_planning_folder}/steering_results.json")
    metadata = load_json(f"{token_planning_folder}/metadata.json")
    new_planning_analysis = _classify_as_planning_vs_not_planning(steering_results, planning_analysis, metadata)
    # updated_folder = token_planning_folder.replace("all_scale", "v_all_scale")
    updated_folder = local_path + "/".join(token_planning_folder.split("/")[-3:])
    os.makedirs(updated_folder, exist_ok=True)
    dump_json(updated_folder + "/updated_planning_analysis.json", new_planning_analysis)

# %%
def _detect_planning(planning_dict):
    keys = []
    for key, value in planning_dict.items():
        if value["new_verdict"] == "Plan":
            keys.append(key)
    return keys

def _detect_cant_says(planning_dict):
    present = False
    for key, value in planning_dict.items():
        if value["new_verdict"] == "Can't say":
            present = True
    return present

def _get_ym_plans(folder):
    token_planning_files = glob.glob(folder + "/*/*.json")
    planning_datas = [load_json(f) for f in token_planning_files]
    y_ms = []
    for data in planning_datas:
        y_ms.extend(_detect_planning(data))
    y_ms = list(set(y_ms))
    return y_ms

def _detect_cs(folder):
    token_planning_files = glob.glob(folder + "/*/*.json")
    planning_datas = [load_json(f) for f in token_planning_files]
    for data in planning_datas:
        if _detect_cant_says(data):
            return True
    return False

def _get_base_and_instruct_plans(iter, root_folder = "../outputs/t_all_scale"):
    base_folder = f"{root_folder}/base/prompt_{iter}"
    instruct_folder = f"{root_folder}/instruct/prompt_{iter}"
    base_yms = None
    instruct_yms = None
    if os.path.exists(base_folder):
        base_yms = _get_ym_plans(base_folder)
    if os.path.exists(instruct_folder):
        instruct_yms = _get_ym_plans(instruct_folder)
    return {
        "base": base_yms,
        "instruct": instruct_yms
    }

def _get_base_and_instruct_cantsays(iter, root_folder = "../outputs/t_all_scale"):
    base_folder = f"{root_folder}/base/prompt_{iter}"
    instruct_folder = f"{root_folder}/instruct/prompt_{iter}"
    if os.path.exists(base_folder):
        base_cs = _detect_cs(base_folder)
    else:
        base_cs = False
    if os.path.exists(instruct_folder):
        instruct_cs = _detect_cs(instruct_folder)
    else:
        instruct_cs = False
    return {
        "base": base_cs,
        "instruct": instruct_cs
    }

# %%
data = load_json("/work/pi_jensen_umass_edu/abhishekmish_umass_edu/plan_trace/data/external/all_examples_og_prompt_with_position_info_and_success_V2.json")

# %%
for iter, entry in enumerate(data):
    ym_plans = _get_base_and_instruct_plans(iter, root_folder = "/home/jnainani_umass_edu/w/plan_trace/outputs/scale_bvi_v7")
    entry["base_plans"] = ym_plans["base"]
    entry["instruct_plans"] = ym_plans["instruct"]
    cs = _get_base_and_instruct_cantsays(iter, root_folder = "/home/jnainani_umass_edu/w/plan_trace/outputs/scale_bvi_v7")    
    entry["base_cs"] = cs["base"]
    entry["instruct_cs"] = cs["instruct"]

def _get_4x4_grid(selected_cases, with_e = False):
    suffix = ""
    if with_e:
        suffix = "_e"
    instruct_plan_base_no_plan = []
    base_plan_instruct_no_plan = []
    both_plans = []
    no_plans = []
    for entry in selected_cases:
        base_planning, instruct_planning = False, False
        if entry["base_plans" + suffix] and len(entry["base_plans" + suffix]) > 0:
            base_planning = True
        elif entry["base_cs" + suffix] == True:
            continue ## skip case if can't say.    
        if entry["instruct_plans" + suffix] and len(entry["instruct_plans" + suffix]) > 0:
            instruct_planning = True
        elif entry["instruct_cs" + suffix] == True:
            continue ## similar skip.

        if base_planning:
            if instruct_planning:         
                both_plans.append(entry)
            else:
                base_plan_instruct_no_plan.append(entry)
        elif instruct_planning:
            instruct_plan_base_no_plan.append(entry)
        else:
            no_plans.append(entry)
    
    print({
        "Both": len(both_plans),
        "Only instruct": len(instruct_plan_base_no_plan),
        "Only base": len(base_plan_instruct_no_plan),
        "None": len(no_plans)
    })

    return {
        "Both": both_plans,
        "Only instruct": instruct_plan_base_no_plan, 
        "Only base": base_plan_instruct_no_plan,
        "None": no_plans 
    }

# %%
for idx, entry in enumerate(data):
    entry["index"] = idx

with open("/work/pi_jensen_umass_edu/jnainani_umass_edu/plan_trace/data/base_vs_instruct_oracle_V4.7.json", "w") as f:
    json.dump(data, f, indent = 2)

# %%
selected_cases = [case for case in data if case["instruct_pass"] == True and case["base_pass"] == False]
len(selected_cases)
# Out:
# 85

# %%
result = _get_4x4_grid(selected_cases)
# Out:
# {'Both': 39, 'Only instruct': 8, 'Only base': 13, 'None': 7}

# %%
def _not_planning(steered_text, original_ym = None):
    """
        - empty string, single character, single string, then classify sa degen.
        - multiple number of 'import' statements in the output without any return statement at the end.
    """
    ## if original_ym is part of the steered text, it's marked as degenerate to prevent a False Positive.
    if original_ym != None and original_ym in steered_text:
        return True

    stripped_text = steered_text.strip()
    if stripped_text == "" or (" " not in stripped_text and len(stripped_text) >= 10):
        return True
    # if any_repeated_substring(steered_text) and (original_ym == "return" or (original_ym != "return" and "return" not in steered_text)):
    #     return True
    # # if original_ym == "return": ## added condition, don't consider planning at 'return' as actual planning evidence of anything actually code related.
    # #     return True
    return False

def _classify_earliest_position_as_planning(steering_results, planning_analysis):
    """
        Logic : 
            If the output is degenerate, we downgrade the Planning to Can't Say.

        Returns, similar new_verdict with 
        {
            "Key": {
                "original_verdict": "",
                "new_verdict": "",
            }
        }
    """
    ym_keys = list(planning_analysis.keys())
    new_planning_analysis = {}
    for y_m in ym_keys:
        new_verdict = planning_analysis[y_m]["final_label"]
        base_suffix = steering_results[y_m]["base_text"]        
        if planning_analysis[y_m]["final_label"] == "Plan":  
            # print("y_m", y_m)
            # if not base_suffix.startswith(y_m) and not all([_downgrade_plan_to_degenerate(e.get("decoded_text", ""), y_m) for e in steering_results[y_m]["steered"]]):
            # print("base suffix starts with y_m", base_suffix.startswith(y_m))
            # print("downgrade plan to degenerate", all([_downgrade_plan_to_degenerate(e.get("decoded_text", ""), y_m) for e in steering_results[y_m]["steered"] if e["coeff"] > -200]))
            # print("not planning", all([_not_planning(e.get("decoded_text", ""), y_m) for e in steering_results[y_m]["steered"] if e["coeff"] > -200]))
            if not base_suffix.startswith(y_m) and not all([_downgrade_plan_to_degenerate(e.get("decoded_text", ""), y_m) for e in steering_results[y_m]["steered"] if e["coeff"] >= -200]):
                # for e in steering_results[y_m]["steered"]:
                #     print(e.get("decoded_text", ""))
                #     print(e.get("coeff", ""))
                #     print(_not_planning(e.get("decoded_text", ""), y_m))
                if all([_not_planning(e.get("decoded_text", ""), y_m) for e in steering_results[y_m]["steered"] if e["coeff"] >= -200]):
                    new_verdict = "Not planning"
                else:
                    new_verdict = "Plan"
                # new_verdict = "Plan"
            else:
                new_verdict = "Can't say"                
            #    new_verdict = "Not planning"
        # elif new_verdict == "Can't say":
        #     new_verdict = "Not planning"
        
        new_planning_analysis[y_m] = {
            "original_verdict": planning_analysis[y_m]["final_label"],
            "new_verdict": new_verdict
        }
    
    return new_planning_analysis
# import pprint
for token_planning_folder in all_tokens:
    metadata = load_json(f"{token_planning_folder}/metadata.json")
    new_planning_analysis = {} ## no plans anyway.
    if metadata["earliest_position"] is not None:
        planning_analysis = load_json(f"{token_planning_folder}/earliest_position_planning_analysis.json")
        steering_results = load_json(f"{token_planning_folder}/earliest_position.json")
        new_planning_analysis = _classify_earliest_position_as_planning(steering_results, planning_analysis)
        # pprint.pprint(planning_analysis)
        # print("--------------------------------")
        # pprint.pprint(steering_results)
        # print("--------------------------------")
        # pprint.pprint(new_planning_analysis)
        # print("--------------------------------")
        # break
    # updated_folder = token_planning_folder.replace("all_scale", "v_all_scale_e")
    updated_folder = "/home/jnainani_umass_edu/w/plan_trace/outputs/scale_bvi_c200/" + "/".join(token_planning_folder.split("/")[-3:])
    os.makedirs(updated_folder, exist_ok=True)
    dump_json(updated_folder + "/updated_planning_analysis.json", new_planning_analysis)

# %%
import pprint

# %%
for token_planning_folder in all_tokens[:5]:
    metadata = load_json(f"{token_planning_folder}/metadata.json")
    new_planning_analysis = {} ## no plans anyway.
    if metadata["earliest_position"] is not None:
        planning_analysis = load_json(f"{token_planning_folder}/earliest_position_planning_analysis.json")
        steering_results = load_json(f"{token_planning_folder}/earliest_position.json")
        print(token_planning_folder)
        new_planning_analysis = _classify_earliest_position_as_planning(steering_results, planning_analysis)
        pprint.pprint(planning_analysis)
        print("--------------------------------")
        pprint.pprint(steering_results)
        print("--------------------------------")
        pprint.pprint(new_planning_analysis)
        print("--------------------------------")

# %%
for iter, entry in enumerate(data):
    ym_plans = _get_base_and_instruct_plans(iter, root_folder = "/home/jnainani_umass_edu/w/plan_trace/outputs/scale_bvi_c200")
    entry["base_plans_e"] = ym_plans["base"]
    entry["instruct_plans_e"] = ym_plans["instruct"]
    cs = _get_base_and_instruct_cantsays(iter, root_folder = "/home/jnainani_umass_edu/w/plan_trace/outputs/scale_bvi_c200")    
    entry["base_cs_e"] = cs["base"]
    entry["instruct_cs_e"] = cs["instruct"]

# %%
selected_cases = [entry for entry in data if entry["base_pass"] == False and entry["instruct_pass"] == True]
len(selected_cases)
# Out:
# 85

# %%
result = _get_4x4_grid(selected_cases, with_e = True)
# Out:
# {'Both': 14, 'Only instruct': 12, 'Only base': 3, 'None': 8}

# %%
with open("/home/jnainani_umass_edu/w/plan_trace/data/base_vs_instruct_oracle_c200.json", "w") as f:
    json.dump(data, f, indent = 2)

# %%
import numpy as np
import matplotlib.pyplot as plt

def _get_2x2_grid(selected_cases, with_e=False):
    suffix = "_e" if with_e else ""
    instruct_plan_base_no_plan = []
    base_plan_instruct_no_plan = []
    both_plans = []
    no_plans = []

    for entry in selected_cases:
        base_planning, instruct_planning = False, False

        if entry.get("base_plans" + suffix) and len(entry["base_plans" + suffix]) > 0:
            base_planning = True
        elif entry.get("base_cs" + suffix) is True:
            continue  # skip if can't say

        if entry.get("instruct_plans" + suffix) and len(entry["instruct_plans" + suffix]) > 0:
            instruct_planning = True
        elif entry.get("instruct_cs" + suffix) is True:
            continue  # skip if can't say

        if base_planning:
            if instruct_planning:
                both_plans.append(entry)
            else:
                base_plan_instruct_no_plan.append(entry)
        elif instruct_planning:
            instruct_plan_base_no_plan.append(entry)
        else:
            no_plans.append(entry)

    return {
        "Both": both_plans,
        "Only instruct": instruct_plan_base_no_plan,
        "Only base": base_plan_instruct_no_plan,
        "None": no_plans,
    }


def compute_4x4_counts(data, with_e=False):
    """
    4 quadrants = (instruct_pass, base_pass) combinations.
    Each quadrant is a 2x2 mini-grid with cells:
      [0,0]=Both Plans, [0,1]=Only Instruct Plans
      [1,0]=Only Base Plans, [1,1]=None Plan

    Layout (rows = instruct pass/fail, cols = base pass/fail):
      rows 0-1: Instruct Pass
      rows 2-3: Instruct Fail
      cols 0-1: Base Pass
      cols 2-3: Base Fail
    """
    # Order in each 2x2
    inner_order = ["Both", "Only instruct", "Only base", "None"]  # TL, TR, BL, BR

    # Confusion-style quadrant layout
    quadrants = [
        ((True,  True),  (0, 0),  "Instruct Pass / Base Pass"),
        ((True,  False), (0, 2),  "Instruct Pass / Base Fail"),
        ((False, True),  (2, 0),  "Instruct Fail / Base Pass"),
        ((False, False), (2, 2),  "Instruct Fail / Base Fail"),
    ]

    counts = np.zeros((4, 4), dtype=int)

    for (ip, bp), (r0, c0), _title in quadrants:
        selected = [case for case in data if case.get("instruct_pass") == ip and case.get("base_pass") == bp]
        buckets = _get_2x2_grid(selected, with_e=with_e)

        # Fill the 2x2
        counts[r0 + 0, c0 + 0] = len(buckets["Both"])         # TL
        counts[r0 + 0, c0 + 1] = len(buckets["Only instruct"])# TR
        counts[r0 + 1, c0 + 0] = len(buckets["Only base"])    # BL
        counts[r0 + 1, c0 + 1] = len(buckets["None"])         # BR

    return counts


def plot_4x4_plan_grid(data, with_e=False, ax=None, cmap="Blues"):
    counts = compute_4x4_counts(data, with_e=with_e)

    if ax is None:
        fig, ax = plt.subplots(figsize=(10, 8))
    else:
        fig = ax.figure

    im = ax.imshow(counts, cmap=cmap)

    # ---- annotate counts in each cell
    vmax = counts.max() if counts.size else 1
    for r in range(4):
        for c in range(4):
            ax.text(
                c, r, str(counts[r, c]),
                ha="center", va="center",
                fontsize=12,
                color="white" if counts[r, c] > 0.6 * vmax else "black"
            )

    # ---- grid lines: thin cell lines + thick quadrant dividers
    ax.set_xticks(np.arange(-0.5, 4, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, 4, 1), minor=True)
    ax.grid(which="minor", linestyle="-", linewidth=1)
    ax.tick_params(which="both", bottom=False, left=False, labelbottom=False, labelleft=False)

    # Thick lines separating 2x2 quadrants
    ax.axhline(1.5, linewidth=3)
    ax.axhline(3.5, linewidth=3)
    ax.axvline(1.5, linewidth=3)
    ax.axvline(3.5, linewidth=3)

    # Outer box
    ax.axhline(-0.5, linewidth=3)
    ax.axvline(-0.5, linewidth=3)

    # ---- inner labels (inside each quadrant, positioned near the 2x2 corners)
    inner_labels = {
        (0, 0): "Both Plans",
        (0, 1): "Only Instruct Plans",
        (1, 0): "Only Base Plans",
        (1, 1): "None Plan",
    }
    # Put the same inner labels in all 4 quadrants, slightly inset
    for r0, c0 in [(0, 0), (0, 2), (2, 0), (2, 2)]:
        for (dr, dc), lab in inner_labels.items():
            r = r0 + dr
            c = c0 + dc
            # label slightly above the number
            ax.text(c, r - 0.32, lab, ha="center", va="center", fontsize=8)

    # ---- outer labels (2 layers): Instruct on left, Base on top
    ax.text(0.5, -0.95, "Base Pass", ha="center", va="center", fontsize=14)
    ax.text(2.5, -0.95, "Base Fail", ha="center", va="center", fontsize=14)

    ax.text(-0.95, 0.5, "Instruct Pass", ha="center", va="center", fontsize=14, rotation=90)
    ax.text(-0.95, 2.5, "Instruct Fail", ha="center", va="center", fontsize=14, rotation=90)

    # Optional: quadrant titles (center of each 2x2)
    quad_titles = {
        (0.5, 0.5): "IP / BP",
        (0.5, 2.5): "IP / BF",
        (2.5, 0.5): "IF / BP",
        (2.5, 2.5): "IF / BF",
    }
    for (y, x), t in quad_titles.items():
        ax.text(x, y, t, ha="center", va="center", fontsize=12, fontweight="bold")

    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04, label="Count")
    ax.set_xlim(-1.2, 3.5)
    ax.set_ylim(3.5, -1.2)  # keep (0,0) at top-left + room for labels
    ax.set_title("4×4 Grid: Pass/Fail quadrants × Planning categories", fontsize=14)
    return ax


# --- usage
# ax = plot_4x4_plan_grid(data, with_e=False)
# plt.show()

# %%
ax = plot_4x4_plan_grid(data, with_e = True)
plt.show()

# %%
ax = plot_4x4_plan_grid(data, with_e = False)
plt.show()
